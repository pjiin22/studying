# %%
import folium

# %% [markdown]
# # folium 기초

# %% [markdown]
# ## **[1] 특정 장소의 지도 시각화하기**
# - [링크](https://xn--yq5bk9r.com/blog/map-coordinates)에 복사한 url[원하는 위치 지도 URL]을 붙여넣고 위도와 경도를 확인하세요.
#
#
# ```
# f = folium.Figure(width=가로길이, height=세로길이)
# m = folium.Map(location=[위도, 경도], zoom_start=줌할정도).add_to(f)
# m.save('test.html') #지도 저장
# m
# ```

# %%
f = folium.Figure(width=700, height=500)
m = folium.Map(location=[37.510781008592716, 127.09607026177875], zoom_start=16).add_to(f)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b78d3e3ad6035ffb3c8a393d9865d32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b78d3e3ad6035ffb3c8a393d9865d32 = L.map(
#                 &quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# 지도 저장하기
m.save('test.html')

# %% [markdown]
# ## **[2] 마커 추가하기**
#
#
# ```
# #장소 표시 마커
# folium.Marker([위도, 경도]
#                 , tooltip=마우스 오버시 나타남
#                 , popup=클릭시 나타남
#                 , icon=folium.Icon(color=색, icon=모양)).add_to(지도)
#
# #원 형태 마커
# folium.CircleMarker([위도, 경도]
#                 , radius=범위
#                 , color=색).add_to(지도)
# ```

# %%
folium.Marker([37.510781008592716, 127.09607026177875]
              , tooltip='롯데월드').add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b78d3e3ad6035ffb3c8a393d9865d32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b78d3e3ad6035ffb3c8a393d9865d32 = L.map(
#                 &quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_0da61ca4a2ee81cc09b387dbd0bb2f99 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             marker_0da61ca4a2ee81cc09b387dbd0bb2f99.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
folium.Marker([37.510781008592716, 127.09607026177875]
              , tooltip='롯데월드'
              , icon = folium.Icon(color='red', icon='star')).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b78d3e3ad6035ffb3c8a393d9865d32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b78d3e3ad6035ffb3c8a393d9865d32 = L.map(
#                 &quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_0da61ca4a2ee81cc09b387dbd0bb2f99 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             marker_0da61ca4a2ee81cc09b387dbd0bb2f99.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_af7fb7a647111b3e3de7445223eca308 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var icon_1112c2dce53e00a89cb421ab8e989249 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_af7fb7a647111b3e3de7445223eca308.setIcon(icon_1112c2dce53e00a89cb421ab8e989249);
#
#
#             marker_af7fb7a647111b3e3de7445223eca308.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
folium.Marker([37.510781008592716, 127.09607026177875]
               , tooltip='롯데월드'
              , icon = folium.Icon(color='red', icon='star')
              , popup = '<iframe src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Lotte_World_Theme_Park.jpg/440px-Lotte_World_Theme_Park.jpg"></iframe>').add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b78d3e3ad6035ffb3c8a393d9865d32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b78d3e3ad6035ffb3c8a393d9865d32 = L.map(
#                 &quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_0da61ca4a2ee81cc09b387dbd0bb2f99 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             marker_0da61ca4a2ee81cc09b387dbd0bb2f99.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_af7fb7a647111b3e3de7445223eca308 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var icon_1112c2dce53e00a89cb421ab8e989249 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_af7fb7a647111b3e3de7445223eca308.setIcon(icon_1112c2dce53e00a89cb421ab8e989249);
#
#
#             marker_af7fb7a647111b3e3de7445223eca308.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_88e0a3ac88343e9579f5ce1164e5663f = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var icon_e1e9c4567553142fe84a13b8acc624f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88e0a3ac88343e9579f5ce1164e5663f.setIcon(icon_e1e9c4567553142fe84a13b8acc624f1);
#
#
#         var popup_b2585118d607446c62326236fab9d4c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2423ef413803b1342c457da035bef4b8 = $(`&lt;div id=&quot;html_2423ef413803b1342c457da035bef4b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe src=&quot;https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Lotte_World_Theme_Park.jpg/440px-Lotte_World_Theme_Park.jpg&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_b2585118d607446c62326236fab9d4c2.setContent(html_2423ef413803b1342c457da035bef4b8);
#
#
#
#         marker_88e0a3ac88343e9579f5ce1164e5663f.bindPopup(popup_b2585118d607446c62326236fab9d4c2)
#         ;
#
#
#
#
#             marker_88e0a3ac88343e9579f5ce1164e5663f.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
folium.CircleMarker([37.510781008592716, 127.09607026177875]
              , color = 'red'
              , radius = 50).add_to(m)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b78d3e3ad6035ffb3c8a393d9865d32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b78d3e3ad6035ffb3c8a393d9865d32 = L.map(
#                 &quot;map_6b78d3e3ad6035ffb3c8a393d9865d32&quot;,
#                 {
#                     center: [37.510781008592716, 127.09607026177875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_0da61ca4a2ee81cc09b387dbd0bb2f99 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             marker_0da61ca4a2ee81cc09b387dbd0bb2f99.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_af7fb7a647111b3e3de7445223eca308 = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var icon_1112c2dce53e00a89cb421ab8e989249 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_af7fb7a647111b3e3de7445223eca308.setIcon(icon_1112c2dce53e00a89cb421ab8e989249);
#
#
#             marker_af7fb7a647111b3e3de7445223eca308.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var marker_88e0a3ac88343e9579f5ce1164e5663f = L.marker(
#                 [37.510781008592716, 127.09607026177875],
#                 {}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var icon_e1e9c4567553142fe84a13b8acc624f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88e0a3ac88343e9579f5ce1164e5663f.setIcon(icon_e1e9c4567553142fe84a13b8acc624f1);
#
#
#         var popup_b2585118d607446c62326236fab9d4c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2423ef413803b1342c457da035bef4b8 = $(`&lt;div id=&quot;html_2423ef413803b1342c457da035bef4b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe src=&quot;https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Lotte_World_Theme_Park.jpg/440px-Lotte_World_Theme_Park.jpg&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_b2585118d607446c62326236fab9d4c2.setContent(html_2423ef413803b1342c457da035bef4b8);
#
#
#
#         marker_88e0a3ac88343e9579f5ce1164e5663f.bindPopup(popup_b2585118d607446c62326236fab9d4c2)
#         ;
#
#
#
#
#             marker_88e0a3ac88343e9579f5ce1164e5663f.bindTooltip(
#                 `&lt;div&gt;
#                      롯데월드
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_1213cd52c5ed3ae7dddb5fa532b512d0.addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
#
#             var circle_marker_1aa99cfe09c9de8f8b1e7d1a5ed2bf46 = L.circleMarker(
#                 [37.510781008592716, 127.09607026177875],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6b78d3e3ad6035ffb3c8a393d9865d32);
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="500"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %% [markdown]
# # folium 응용
# 서울시의 이디야, 투썸 위치 시각화 & 지리적 분포 차이 확인하기

# %%
import json
import folium
import pandas as pd

# %% [markdown]
# ## **[1] 서울시 구별 경계 데이터 가져오기**
